# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ABOUT THE DATASET
# This dataset is about World Happiness Report a survey of the state of global happiness.Reports were published in year 2012,2013,2015,2016 and in 2017 a report was published which marked 155 countries and it was relased at the United Nations at an event celebrating International Day of Happiness on March 20th.This report gain global recognition and was used as happiness indicators to inform their policy-making decisions.The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %%
df=pd.read_csv('happeness_score.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# ABOUT THE VARIABLES
#
# The datset is divided into two major variable input n output variables.The attribute of input variables are as follow"-
# 1 - Country
# 2 - Region
# 3 - Happiness Rank
# 4 - Standard Error
# 5 - Economy (GDP per Capita)
# 6 - Family
# 7 - Health (Life Expectancy)
# 8 - Freedom
# 9 - Trust (Government Corruption)
# 10 - Generosity
# 11 - Dystopia Residual
# The attribute for output variable is:-Happiness Score
#
# We can see that there are 158 rows and 12 columns including output variable.
#
# Checking the dataset by applying various functions as mentioned below:-
# i head()
# ii tail
# iii shape( which shows the no. of rows n columns)
# iv data types(here we can see whether my data is numerical or categorical)

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# It is observed that both numerical and categroical data is present in th dataset.

# %%
df.columns                 #Checking the different columns present.
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.isnull().sum()                      #Checking if any null value is present in the dataset.
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())              #using heatmap for better visualization of null value.
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# With the help of above function we can get the detailed information about the data like Range index,Colunm name, non-null count, data type and memory usage.

# %%
df['Country'].unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#        'Netherlands', 'Sweden', 'New Zealand', 'Australia', 'Israel',
#        'Costa Rica', 'Austria', 'Mexico', 'United States', 'Brazil',
#        'Luxembourg', 'Ireland', 'Belgium', 'United Arab Emirates',
#        'United Kingdom', 'Oman', 'Venezuela', 'Singapore', 'Panama',
#        'Germany', 'Chile', 'Qatar', 'France', 'Argentina',
#        'Czech Republic', 'Uruguay', 'Colombia', 'Thailand',
#        'Saudi Arabia', 'Spain', 'Malta', 'Taiwan', 'Kuwait', 'Suriname',
#        'Trinidad and Tobago', 'El Salvador', 'Guatemala', 'Uzbekistan',
#        'Slovakia', 'Japan', 'South Korea', 'Ecuador', 'Bahrain', 'Italy',
#        'Bolivia', 'Moldova', 'Paraguay', 'Kazakhstan', 'Slovenia',
#        'Lithuania', 'Nicaragua', 'Peru', 'Belarus', 'Poland', 'Malaysia',
#        'Croatia', 'Libya', 'Russia', 'Jamaica', 'North Cyprus', 'Cyprus',
# ...

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df.nunique().to_frame()
# Out:
#                                  0
# Country                        158
# Region                          10
# Happiness Rank                 157
# Happiness Score                157
# Standard Error                 153
# Economy (GDP per Capita)       158
# Family                         158
# Health (Life Expectancy)       157
# Freedom                        158
# Trust (Government Corruption)  157
# Generosity                     158
# Dystopia Residual              158

# %% [markdown]
# Checked the unique value in column name Country,Region and also checked the number of unqiue values present in each column.

# %%
df.duplicated().sum()                      #looking of duplicate value.
# Out:
# 0

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# After doing all the required changes in the dataset and as there no negative values present in the dataset it looks good to continue the data analysing. Following observations can be done on the bases of describe function.
# i Count of all the coulumns are equal.
# ii Left skewness of data is present because in few columns like Happiness Score,Economy (GDP per Capital),Family median is more than mean.
# iii Data is also normally distrubted as in many columns for eg.Happiness Rank,density,Dystopia Residual mean and median have same values.
# iv There are also chances of outlier in some columns becasuse there is major difference in the values of 75% and max in some columns.

# %%
df1=df.drop(['Country', 'Region'], axis=1)                   #Droping these two columns because they will have no bearing on the analysis

# %%
df1.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df1.corr(),linewidth=0.3,annot=True,linecolor='blue',fmt="0.2f")
# Out:
# <Axes: >

# %%
df1.set_index("Happiness Rank", inplace = True) #Making Happiness Rank column index No.

# %%
df1                #Will be using the dataset for futhure analysis
# Out:
#                 Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Happiness Rank
# 1                         7.587         0.03411                   1.39651
# 2                         7.561         0.04884                   1.30232
# 3                         7.527         0.03328                   1.32548
# 4                         7.522         0.03880                   1.45900
# 5                         7.427         0.03553                   1.32629
# ...                         ...             ...                       ...
# 154                       3.465         0.03464                   0.22208
# 155                       3.340         0.03656                   0.28665
# 156                       3.006         0.05015                   0.66320
# 157                       2.905         0.08658                   0.01530
# 158                       2.839         0.06727                   0.20868
#
#                  Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# DATA VISUALIZATION
# Various graphs are used to inorder to understand how the data is distributed,it's skweness, scattered.

# %%
sns.distplot(df1['Happiness Score'],color='b')
# Out:
# <Axes: xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df1['Standard Error'],color='b')
# Out:
# <Axes: xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df1['Economy (GDP per Capita)'],color='b')
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df1['Family'],color='b')
# Out:
# <Axes: xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df1['Health (Life Expectancy)'],color='b')
# Out:
# <Axes: xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df1['Freedom'],color='b')
# Out:
# <Axes: xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df1['Trust (Government Corruption)'],color='b')
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df1['Trust (Government Corruption)'],color='b')
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df1['Generosity'],color='b')
# Out:
# <Axes: xlabel='Generosity', ylabel='Density'>

# %%
sns.histplot(data=df1,x='Dystopia Residual',color='r')
# Out:
# <Axes: xlabel='Dystopia Residual', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Standard Error',color='r')
# Out:
# <Axes: xlabel='Standard Error', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Economy (GDP per Capita)',color='r')
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Family',color='r')
# Out:
# <Axes: xlabel='Family', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Health (Life Expectancy)',color='r')
# Out:
# <Axes: xlabel='Health (Life Expectancy)', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Freedom',color='r')
# Out:
# <Axes: xlabel='Freedom', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Trust (Government Corruption)',color='r')
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Generosity',color='r')
# Out:
# <Axes: xlabel='Generosity', ylabel='Count'>

# %%
sns.histplot(data=df1,x='Dystopia Residual',color='r')
# Out:
# <Axes: xlabel='Dystopia Residual', ylabel='Count'>

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df1,palette='bright')
plt.title('Standard Error VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Standard Error VS Happiness Score')

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df1,palette='bright')
plt.title('Economy (GDP per Capita) VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Economy (GDP per Capita) VS Happiness Score')

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df1,palette='bright')
plt.title('Family VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Family VS Happiness Score')

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df1,palette='bright')
plt.title('Health (Life Expectancy)  VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Health (Life Expectancy)  VS Happiness Score')

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df1,palette='bright')
plt.title('Economy (GDP per Capita) VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Economy (GDP per Capita) VS Happiness Score')

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df1,palette='bright')
plt.title('Freedom VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Freedom VS Happiness Score')

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df1,palette='bright')
plt.title('Trust (Government Corruption) VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Trust (Government Corruption) VS Happiness Score')

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df1,palette='bright')
plt.title('Generosity VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Generosity VS Happiness Score')

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df1,palette='bright')
plt.title('Dystopia Residual VS Happiness Score')
# Out:
# Text(0.5, 1.0, 'Dystopia Residual VS Happiness Score')

# %% [markdown]
# Using regression plots to creates the relationship between two numerical variables using scatter points and a fitted regression line.If the points are widely scattered, it suggests a weaker relationship between the variables.

# %%
sns.regplot(data=df1, x="Standard Error", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.regplot(data=df1, x="Economy (GDP per Capita)", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.regplot(data=df1, x="Family", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Family', ylabel='Happiness Score'>

# %%
sns.regplot(data=df1, x="Health (Life Expectancy)", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.regplot(data=df1, x="Freedom", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.regplot(data=df1, x="Trust (Government Corruption)", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
sns.regplot(data=df1, x="Generosity", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.regplot(data=df1, x="Dystopia Residual", y="Happiness Score", color='r')
# Out:
# <Axes: xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
df1.plot(kind='box',subplots=True,layout=(2,5))     #checking the outliers in the dataset
# Out:
# Happiness Score                     Axes(0.125,0.53;0.133621x0.35)
# Standard Error                   Axes(0.285345,0.53;0.133621x0.35)
# Economy (GDP per Capita)          Axes(0.44569,0.53;0.133621x0.35)
# Family                           Axes(0.606034,0.53;0.133621x0.35)
# Health (Life Expectancy)         Axes(0.766379,0.53;0.133621x0.35)
# Freedom                             Axes(0.125,0.11;0.133621x0.35)
# Trust (Government Corruption)    Axes(0.285345,0.11;0.133621x0.35)
# Generosity                        Axes(0.44569,0.11;0.133621x0.35)
# Dystopia Residual                Axes(0.606034,0.11;0.133621x0.35)
# dtype: object

# %% [markdown]
# From the above plots it is observeed that outliers are present in few columns of the dataset.Inorder to remove thoes outliers zscore is imported and as the threshold value for zscore is between -3 to +3 keeping that in mind removing the outliers.

# %%
from scipy.stats import zscore
out_liers=df1[['Standard Error','Trust (Government Corruption)','Family','Generosity','Dystopia Residual']]
z=np.abs(zscore(out_liers))
z
# Out:
#                 Standard Error  Trust (Government Corruption)    Family  \
# Happiness Rank
# 1                     0.805926                       2.309652  1.320281
# 2                     0.055889                       0.016480  1.514458
# 3                     0.854487                       2.842774  1.361054
# 4                     0.531526                       1.852081  1.251922
# 5                     0.722845                       1.555725  1.221204
# ...                        ...                            ...       ...
# 154                   0.774917                       3.413922  0.800520
# 155                   0.662582                       0.529210  2.346860
# 156                   0.132534                       0.381419  1.901086
# 157                   2.263962                       0.357715  2.118467
# 158                   1.134182                       0.301803  3.134725
#
#                 Generosity  Dystopia Residual
# Happiness Rank
# ...

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157]),
#  array([1, 0, 0, 0, 3, 2, 1, 4, 2]))

# %%
data=df1[(z<3).all(axis=1)]
data.shape
# Out:
# (149, 9)

# %%
print("dataloss",((df1.shape[0]-data.shape[0])/df1.shape[0])*100)  #data loss is more not making any changes in the dataset
# Out:
# dataloss 5.69620253164557

# %%
df1
# Out:
#                 Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Happiness Rank
# 1                         7.587         0.03411                   1.39651
# 2                         7.561         0.04884                   1.30232
# 3                         7.527         0.03328                   1.32548
# 4                         7.522         0.03880                   1.45900
# 5                         7.427         0.03553                   1.32629
# ...                         ...             ...                       ...
# 154                       3.465         0.03464                   0.22208
# 155                       3.340         0.03656                   0.28665
# 156                       3.006         0.05015                   0.66320
# 157                       2.905         0.08658                   0.01530
# 158                       2.839         0.06727                   0.20868
#
#                  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df1.skew()                      #checking the skewness of data
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
from scipy.stats import boxcox                         #removing the skewness by using log transform methos

# %%
df1['Standard Error']=boxcox(df1['Standard Error'],0)

# %%
df1.skew().sort_values(ascending=False)
# Out:
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Standard Error                   0.484623
# Happiness Score                  0.097769
# Dystopia Residual               -0.238911
# Economy (GDP per Capita)        -0.317575
# Freedom                         -0.413462
# Health (Life Expectancy)        -0.705328
# Family                          -1.006893
# dtype: float64

# %%
df1.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.210296
# Standard Error                       -0.210296        1.000000
# Economy (GDP per Capita)              0.780966       -0.223477
# Family                                0.740605       -0.133812
# Health (Life Expectancy)              0.724200       -0.320471
# Freedom                               0.568211       -0.171718
# Trust (Government Corruption)         0.395199       -0.187226
# Generosity                            0.180319       -0.124805
# Dystopia Residual                     0.530474        0.052531
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.223477 -0.133812
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %% [markdown]
# Happiness Score shows positive correlation with Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, and Trust (Government Corruption). It can be observed that if these factors increase, then Happiness Score can also increase.There is a weak negative correlation with Standard Error.This means that countries with higher standard errors in Happiness Score might tend to have slightly lower happiness scores. There's also a weak correlation with Dystopia Residual.

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df1.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Making the data ready for applying various models but diving it into dependent and independent variable. Spliting it in Test and train.

# %%
X=df1.drop(columns =['Happiness Score'])
Y=df1['Happiness Score']

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()
X=st.fit_transform(X)
X
# Out:
# array([[-0.91537607,  1.36962124,  1.32028142, ...,  2.30965159,
#          0.47103971,  0.75825809],
#        [ 0.22936393,  1.13522625,  1.51445776, ..., -0.01647953,
#          1.57585637,  1.09285682],
#        [-0.99393518,  1.19286069,  1.36105403, ...,  2.8427738 ,
#          0.8242928 ,  0.71233526],
#        ...,
#        [ 0.31377459, -0.45524543, -1.90108634, ...,  0.38141902,
#          1.85689094, -3.20843049],
#        [ 2.05515887, -2.06756644, -2.1184666 , ..., -0.35771452,
#         -0.31694987, -0.48198451],
#        [ 1.2503867 , -1.58633379, -3.13472485, ..., -0.30180313,
#         -0.5581534 , -0.96361241]])

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score,GridSearchCV

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33, random_state=43)
print('Training size:',X_train.shape)
print('Training target size:',Y_train.shape)
print('Test size:',X_test.shape)
print('Test target size:',Y_test.shape)
# Out:
# Training size: (105, 8)
# Training target size: (105,)
# Test size: (53, 8)
# Test target size: (53,)

# %%
X
# Out:
# array([[-0.91537607,  1.36962124,  1.32028142, ...,  2.30965159,
#          0.47103971,  0.75825809],
#        [ 0.22936393,  1.13522625,  1.51445776, ..., -0.01647953,
#          1.57585637,  1.09285682],
#        [-0.99393518,  1.19286069,  1.36105403, ...,  2.8427738 ,
#          0.8242928 ,  0.71233526],
#        ...,
#        [ 0.31377459, -0.45524543, -1.90108634, ...,  0.38141902,
#          1.85689094, -3.20843049],
#        [ 2.05515887, -2.06756644, -2.1184666 , ..., -0.35771452,
#         -0.31694987, -0.48198451],
#        [ 1.2503867 , -1.58633379, -3.13472485, ..., -0.30180313,
#         -0.5581534 , -0.96361241]])

# %%
Y
# Out:
# Happiness Rank
# 1      7.587
# 2      7.561
# 3      7.527
# 4      7.522
# 5      7.427
#        ...
# 154    3.465
# 155    3.340
# 156    3.006
# 157    2.905
# 158    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
lm=LinearRegression()
lm.fit(X_train,Y_train)
lm.score(X_test,Y_test)
pred1=lm.predict(X_train)
pred=lm.predict(X_test)
print("Mean absolute Error",mean_absolute_error(Y_test,pred))
print("Mean squared error",mean_squared_error(Y_test,pred))
print("r2 Score on test data",r2_score(Y_test,pred)*100)  
print("r2 Score on training data",r2_score(Y_train,pred1)*100)
# Out:
# Mean absolute Error 0.0002619613854309369
# Mean squared error 9.063441624421579e-08
# r2 Score on test data 99.99999286893662
# r2 Score on training data 99.99999456759755

# %%
rf=RandomForestRegressor()
rf.fit(X_train,Y_train)
rf.score(X_test,Y_test)
pred1=rf.predict(X_train)
pred=rf.predict(X_test)
print("Mean absolute Error",mean_absolute_error(Y_test,pred))
print("Mean squared error",mean_squared_error(Y_test,pred))
print("r2 Score on test data",r2_score(Y_test,pred)*100)  
print("r2 Score on training data",r2_score(Y_train,pred1)*100)
# Out:
# Mean absolute Error 0.30371679245283034
# Mean squared error 0.1708795501339626
# r2 Score on test data 86.55529596065789
# r2 Score on training data 98.2613465640791

# %%
sv=SVR()
sv.fit(X_train,Y_train)
sv.score(X_test,Y_test)
pred1=sv.predict(X_train)
pred=sv.predict(X_test)
print("Mean absolute Error",mean_absolute_error(Y_test,pred))
print("Mean squared error",mean_squared_error(Y_test,pred))
print("r2 Score on test data",r2_score(Y_test,pred)*100)   
print("r2 Score on training data",r2_score(Y_train,pred1)*100)
# Out:
# Mean absolute Error 0.17165878582745317
# Mean squared error 0.06443014995431555
# r2 Score on test data 94.93067311643141
# r2 Score on training data 98.32211392508137

# %%
ar=AdaBoostRegressor()
ar.fit(X_train,Y_train)
ar.score(X_test,Y_test)
pred1=ar.predict(X_train)
pred=ar.predict(X_test)
print("Mean absolute Error",mean_absolute_error(Y_test,pred))
print("Mean squared error",mean_squared_error(Y_test,pred))
print("r2 Score on test data",r2_score(Y_test,pred)*100) 
print("r2 Score on training data",r2_score(Y_train,pred1)*100)
# Out:
# Mean absolute Error 0.331691799314357
# Mean squared error 0.20889400326836388
# r2 Score on test data 83.56434080418194
# r2 Score on training data 95.7794623696474

# %% [markdown]
# All the models above shows R-squared Score on test and train data also Mean absolute error and Mean squared error can be seen. From the above models the best suited model for this dataset is LinearRegression model with 99% accuracy but still will be further to do cross validation on all the models to select the best suited model the given dataset.

# %%
cv=cross_val_score(rf,X,Y,scoring="r2")
print(cv)
print(cv.mean())
print(cv.std())
# Out:
# [-6.89238398 -0.93535407 -0.75966708 -1.81037795 -5.50933418]
# -3.1814234502439085
# 2.529027233682615

# %%
cv1=cross_val_score(sv,X,Y)
print(cv1)
print(cv1.mean())
print(cv1.std())
# Out:
# [-11.2885847    0.17570152   0.82023689   0.0983064   -6.01438325]
# -3.2417446294502112
# 4.72808064580735

# %%
cv2=cross_val_score(lm,X,Y)
print(cv2)
print(cv2.mean())
print((cv2.std()))
# Out:
# [0.99999944 0.99999834 0.99999836 0.99999536 0.99999943]
# 0.9999981859701389
# 1.4945575226495029e-06

# %%
cv3=cross_val_score(ar,X,Y)
print(cv3)
print(cv3.mean())
print((cv3.std()))
# Out:
# [-9.02646184 -7.52993121 -2.89524884 -5.93975381 -6.27609712]
# -6.333498565811366
# 2.0328990775216105

# %% [markdown]
# After Cross Valadition Score it is observed that the best suited model is Linear Regression.

# %%
param= {'copy_X': [True,False], 
               'fit_intercept': [True,False], 
               'n_jobs': [1,5,10,15,None], 
               'positive': [True,False]}

# %%
gscv = GridSearchCV(lm, param, cv=5)
gscv.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [1, 5, 10, 15, None],
#                          'positive': [True, False]})

# %%
import joblib
joblib.dump(lm,'Happiness.obj')
lm_from_joblib=joblib.load('Happiness.obj')
lm_from_joblib.predict(X_test)
# Out:
# array([5.12315766, 4.83929658, 3.6550473 , 7.5868147 , 5.21191564,
#        5.60459618, 3.84500487, 5.28638453, 6.90126344, 6.29815453,
#        7.27768282, 4.29671787, 4.88454562, 5.19229768, 4.69403189,
#        7.52691868, 7.22571479, 4.60968643, 6.98251585, 7.1997903 ,
#        5.19378142, 4.95943174, 5.26790522, 4.07676088, 6.26927514,
#        3.81934488, 7.56087735, 6.50507223, 5.75440798, 4.63349351,
#        5.88974564, 4.78645573, 6.94019097, 2.83903999, 4.85760533,
#        5.69534609, 6.29470535, 4.29254265, 5.9870637 , 5.82413431,
#        5.6888101 , 5.47383273, 7.2839585 , 5.5480744 , 5.4285494 ,
#        5.82831395, 4.41932668, 3.90376952, 6.81019042, 4.56470408,
#        4.89750106, 5.19235473, 5.83261881])

# %%
import pickle
filename="Happiness.pkl1"
pickle.dump(lm,open(filename,'wb'))
loaded_model1=pickle.load(open(filename,'rb'))
result=loaded_model1.predict(X_test)
print(result)
# Out:
# [5.12315766 4.83929658 3.6550473  7.5868147  5.21191564 5.60459618
#  3.84500487 5.28638453 6.90126344 6.29815453 7.27768282 4.29671787
#  4.88454562 5.19229768 4.69403189 7.52691868 7.22571479 4.60968643
#  6.98251585 7.1997903  5.19378142 4.95943174 5.26790522 4.07676088
#  6.26927514 3.81934488 7.56087735 6.50507223 5.75440798 4.63349351
#  5.88974564 4.78645573 6.94019097 2.83903999 4.85760533 5.69534609
#  6.29470535 4.29254265 5.9870637  5.82413431 5.6888101  5.47383273
#  7.2839585  5.5480744  5.4285494  5.82831395 4.41932668 3.90376952
#  6.81019042 4.56470408 4.89750106 5.19235473 5.83261881]
