# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. ABOUT THE DATASET
# Health insurance is a type of insurance that covers medical expenses that arise due to an illness. The main purpose of medical insurance is to receive the best medical care without any strain on finances. Based on certain input features such as age , bmi,no of dependents ,smoker ,region medical insurance is calculated.

# %%
data1=pd.read_csv('Medical_cost_insurance.csv')
data1
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# 2.ABOUT THE VARIABLES
#
# 2.1 The datset is divided into two major variable input n output as mentioned above.The attribute of input variables are as follow-
# 1 - age
# 2 - sex
# 3 - bmi
# 4 - chlidren
# 5 - smoker
# 6 - regions
# The attribute for output variable is:-CHarges
#
# 2.2 We can see that there are 1338 rows and 7 columns including output variable.
#
# 3. Checking the dataset by applying various functions as mentioned below:-
# i head()
# ii tail()
# iii shape( which shows the no. of rows n columns)
# iv data types(here we can see whether my data is numerical or categorical)

# %%
data1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data1.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data1.shape # checking the size of data n out of 7 column 1 is target value
# Out:
# (1338, 7)

# %%
df.dtypes # checking whether data is numerical or categorical
# Out:
# age           int64
# sex           int64
# bmi         float64
# children      int64
# smoker        int64
# region        int64
# charges     float64
# dtype: object

# %% [markdown]
# It can be seen that some of the data is numerical and some are categorical.

# %%
data1.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data1.isnull().sum()   #There is no null value present in the dataset.
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# With the help of above function we can get the detailed information about the data like Range index,Colunm name, non-null count, data type and memory usage.

# %%
sns.heatmap(data1.isnull()) #x axis column name n y axis range, way to check null value by color coding, there only 1 color because there is no null value
# Out:
# <Axes: >

# %% [markdown]
# Inorder to understand the null value in color code format and to have good visual heat map is used to represent the data.As there no null value that why the same color is apperaing on the heat map.

# %%
data1.nunique().to_frame()       #Checked the no. of unique values in the column
# Out:
#              0
# age         47
# sex          2
# bmi        548
# children     6
# smoker       2
# region       4
# charges   1337

# %%
for c in data1.columns:
    print(data1[c].value_counts())
    print('\n')
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64
#
#
# 1639.56310     2
# 16884.92400    1
# 29330.98315    1
# 2221.56445     1
# 19798.05455    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %%
data1['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data1['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data1['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
data1.duplicated().sum()     #sum of duplicate row present in the dataset
# Out:
# 1

# %%
data1.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# After doing all the required changes in the dataset and as there no negative values present in the dataset it looks good to continue the data analysing.
# Following observations can be done on the bases of describe function.
# i Count of all the coulumns are equal.
# ii Right skewness of data is present because in columns charges because mean is more than median.
# iii Data is also normally distrubted as in many columns for eg.age,bmi,chlidren mean and median have same values. iv There are also chances of outlier in some columns becasuse there is major difference in the values of 75% and max in column charges.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data1.describe(),linewidth=0.3,annot=True,linecolor='blue',cmap='Spectral',fmt="0.2f")
# Out:
# <Axes: >

# %% [markdown]
# Heatmap represention of data after about mean,medain for a better understanding.

# %%
clean_data = {'sex': {'male' : 0 , 'female' : 1} ,
                 'smoker': {'no': 0 , 'yes' : 1},
                   'region' : {'northwest':0, 'northeast':1,'southeast':2,'southwest':3}
               }
df = df.copy()
df.replace(clean_data, inplace=True)

# %% [markdown]
# As it is observed above the some of the is categorical so, converting  it in numerical data.Inorder to carry out the further processing of the dataset.

# %%
df # After convering the categorical data into numerical data this is the final dataset ready for further steps.
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Data Visualiation
# 1. Using count plot for better understanding of the variable composition in the data.

# %%
print(df['sex'].value_counts())
ax=sns.countplot(x='sex',data=df)
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
print(df['smoker'].value_counts())
ax=sns.countplot(x='smoker',data=df)
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
print(df['age'].value_counts())
ax=sns.countplot(x='age',data=df)
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
plt.figure(figsize=(12,9))
plt.title('Sex vs Charge')
sns.barplot(x='sex',y='charges',data=df)
# Out:
# <Axes: title={'center': 'Sex vs Charge'}, xlabel='sex', ylabel='charges'>

# %% [markdown]
# Bar chart is created to visualize the relationship between two variables in the Dataset.

# %%
plt.figure(figsize=(12,9))
plt.title('Smoker vs Charge')
sns.barplot(x='smoker',y='charges',data=df)
# Out:
# <Axes: title={'center': 'Smoker vs Charge'}, xlabel='smoker', ylabel='charges'>

# %%
plt.figure(figsize=(12,9))
plt.title('Region vs Charges')
sns.barplot(x='region',y='charges',data=df)
# Out:
# <Axes: title={'center': 'Region vs Charges'}, xlabel='region', ylabel='charges'>

# %%
plt.figure(figsize=(12,9))
plt.title('Children vs Charge')
sns.barplot(x='children',y='charges',data=df)
# Out:
# <Axes: title={'center': 'Children vs Charge'}, xlabel='children', ylabel='charges'>

# %% [markdown]
# From the below graphical presentation we can the see that thre is right skweness and somewhere normal distribution of data.

# %%
sns.histplot(data=df,x='bmi',bins=30,kde=True,color='r')
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(data=df,x='bmi',bins=30,kde=True,color='r')
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(data=df,x='charges',bins=30,kde=True,color='r')
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.histplot(df['region'],kde=True,color='r')
# Out:
# <Axes: xlabel='region', ylabel='Count'>

# %%
sns.scatterplot(x='bmi',y='charges',hue='sex',data=df,palette='bright')
plt.title('BMI VS Charge')
# Out:
# Text(0.5, 1.0, 'BMI VS Charge')

# %%
sns.scatterplot(x='age',y='charges',hue='sex',data=df,palette='bright')
plt.title('AGE VS Charge')
# Out:
# Text(0.5, 1.0, 'AGE VS Charge')

# %%
sns.scatterplot(x='sex',y='charges',hue='sex',data=df,palette='bright')
plt.title('SEX VS Charge')
# Out:
# Text(0.5, 1.0, 'SEX VS Charge')

# %%
sns.scatterplot(x='children',y='charges',hue='sex',data=df,palette='bright')
plt.title('CHILDREN VS Charge')
# Out:
# Text(0.5, 1.0, 'CHILDREN VS Charge')

# %%
sns.scatterplot(x='smoker',y='charges',hue='sex',data=df,palette='bright')
plt.title('SMOKER VS Charge')
# Out:
# Text(0.5, 1.0, 'SMOKER VS Charge')

# %%
plt.figure(figsize=(10,7))
plt.title('Smoker vs Charge')
sns.barplot(x='smoker',y='charges',data=df,palette='bright',hue='sex')
# Out:
# <Axes: title={'center': 'Smoker vs Charge'}, xlabel='smoker', ylabel='charges'>

# %%
plt.figure(figsize=(10,7))
plt.title('region vs Charge')
sns.barplot(x='region',y='charges',data=df,palette='bright',hue='sex')
# Out:
# <Axes: title={'center': 'region vs Charge'}, xlabel='region', ylabel='charges'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(data=df['age'], palette="Paired")
# Out:
# <Axes: >

# %%
sns.boxplot(data=df['bmi'], palette="Paired")
# Out:
# <Axes: >

# %%
sns.boxplot(data=df['children'], palette="Paired")
# Out:
# <Axes: >

# %%
sns.boxplot(data=df['region'], palette="Paired")
# Out:
# <Axes: >

# %%
df.plot(kind='box',subplots=True,layout=(3,4))
# Out:
# age            Axes(0.125,0.653529;0.168478x0.226471)
# sex         Axes(0.327174,0.653529;0.168478x0.226471)
# bmi         Axes(0.529348,0.653529;0.168478x0.226471)
# children    Axes(0.731522,0.653529;0.168478x0.226471)
# smoker         Axes(0.125,0.381765;0.168478x0.226471)
# region      Axes(0.327174,0.381765;0.168478x0.226471)
# charges     Axes(0.529348,0.381765;0.168478x0.226471)
# dtype: object

# %% [markdown]
# From the above plots it is observeed that outliers are present in few columns of the dataset.Inorder to remove thoes outliers zscore is imported and as the threshold value for zscore is between -3 to +3 keeping that in mind removing the outliers.

# %%
from scipy.stats import zscore
out_liers=df[['bmi','smoker','charges']]
z=np.abs(zscore(out_liers))
z
# Out:
#            bmi    smoker   charges
# 0     0.453320  1.970587  0.298584
# 1     0.509621  0.507463  0.953689
# 2     0.383307  0.507463  0.728675
# 3     1.305531  0.507463  0.719843
# 4     0.292556  0.507463  0.776802
# ...        ...       ...       ...
# 1333  0.050297  0.507463  0.220551
# 1334  0.206139  0.507463  0.914002
# 1335  1.014878  0.507463  0.961596
# 1336  0.797813  0.507463  0.930362
# 1337  0.261388  1.970587  1.311053
#
# [1338 rows x 3 columns]

# %%
data=df[(z<3).all(axis=1)]
data.shape
# Out:
# (1327, 7)

# %%
df1=print("Data Loose Percentage",((df.shape[0]-data.shape[0])/df.shape[0])*100)
# Out:
# Data Loose Percentage 0.8221225710014948

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1327 rows x 7 columns]

# %% [markdown]
# Checking the skewness of the data and then removing it by using cuberoot and squareroot method.Skewness values within the range of -1 and -0.5 (negative skewed) or 0.5 and 1(positive skewed).

# %%
data.skew()
# Out:
# age         0.055031
# sex        -0.013580
# bmi         0.203726
# children    0.933380
# smoker      1.498166
# region     -0.033371
# charges     1.453405
# dtype: float64

# %%
data[['smoker','bmi','children','charges']]=np.cbrt(data[['smoker','bmi','children','charges']])

# %%
data.skew()
# Out:
# age         0.055031
# sex        -0.013580
# bmi        -0.126801
# children   -0.101115
# smoker      1.498166
# region     -0.033371
# charges     0.490528
# dtype: float64

# %%
data.skew().sort_values(ascending=False)
# Out:
# smoker      1.498166
# charges     0.490528
# age         0.055031
# sex        -0.013580
# region     -0.033371
# children   -0.101115
# bmi        -0.126801
# dtype: float64

# %%
sns.distplot(data['smoker'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <Axes: xlabel='smoker', ylabel='Density'>

# %%
data.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020610  0.121131  0.051882 -0.027158  0.001373  0.457594
# sex      -0.020610  1.000000  0.040344  0.016302  0.075665  0.000260  0.027209
# bmi       0.121131  0.040344  1.000000  0.020754 -0.009686  0.157522  0.153833
# children  0.051882  0.016302  0.020754  1.000000  0.013991  0.016549  0.134573
# smoker   -0.027158  0.075665 -0.009686  0.013991  1.000000 -0.004268  0.725528
# region    0.001373  0.000260  0.157522  0.016549 -0.004268  1.000000 -0.032431
# charges   0.457594  0.027209  0.153833  0.134573  0.725528 -0.032431  1.000000

# %%
plt.figure(figsize=(8,7))
sns.heatmap(data.corr(),annot=True) 
plt.show()

# %%
data
# Out:
#       age  sex       bmi  children  smoker  region    charges
# 0      19    0  3.032970   0.00000     1.0       3  25.654666
# 1      18    1  3.232290   1.00000     0.0       2  11.994331
# 2      28    1  3.207534   1.44225     0.0       2  16.447599
# 3      33    1  2.831656   0.00000     0.0       1  28.013799
# 4      32    1  3.068073   0.00000     0.0       1  15.695891
# ...   ...  ...       ...       ...     ...     ...        ...
# 1333   50    1  3.140367   1.44225     0.0       1  21.967271
# 1334   18    0  3.172154   0.00000     0.0       0  13.017690
# 1335   18    0  3.327713   0.00000     0.0       2  11.768318
# 1336   21    0  2.954880   0.00000     0.0       3  12.615872
# 1337   61    0  3.074787   0.00000     1.0       1  30.773007
#
# [1327 rows x 7 columns]

# %%
x=data.iloc[:,0:-1]
x
# Out:
#       age  sex       bmi  children  smoker  region
# 0      19    0  3.032970   0.00000     1.0       3
# 1      18    1  3.232290   1.00000     0.0       2
# 2      28    1  3.207534   1.44225     0.0       2
# 3      33    1  2.831656   0.00000     0.0       1
# 4      32    1  3.068073   0.00000     0.0       1
# ...   ...  ...       ...       ...     ...     ...
# 1333   50    1  3.140367   1.44225     0.0       1
# 1334   18    0  3.172154   0.00000     0.0       0
# 1335   18    0  3.327713   0.00000     0.0       2
# 1336   21    0  2.954880   0.00000     0.0       3
# 1337   61    0  3.074787   0.00000     1.0       1
#
# [1327 rows x 6 columns]

# %%
y=data.iloc[:,-1]
y
# Out:
# 0       25.654666
# 1       11.994331
# 2       16.447599
# 3       28.013799
# 4       15.695891
#           ...
# 1333    21.967271
# 1334    13.017690
# 1335    11.768318
# 1336    12.615872
# 1337    30.773007
# Name: charges, Length: 1327, dtype: float64

# %%
x.shape
# Out:
# (1327, 6)

# %%
y.shape
# Out:
# (1327,)

# %% [markdown]
# X = data_pre.drop('charges',axis=1).values
# y = data_pre['charges'].values.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.40,random_state=42)

# %%
x_train.shape
# Out:
# (796, 6)

# %%
x_test.shape
# Out:
# (531, 6)

# %%
y_train.shape
# Out:
# (796,)

# %%
y_test.shape
# Out:
# (531,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, GridSearchCV

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
lm.score(x_train,y_train)
lm.score(x_test,y_test)
pred1=lm.predict(x_train)
pred=lm.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.995223395082229
# Mean squared error 10.24437200083868
# r2 Score on test data 0.7645306956597147
# r2 Score on training data 0.7846698704033142

# %% [markdown]
#  This model seems to be performing well, with a good R-squared score on the test and train data.

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
rf.score(x_test,y_test)
pred1=rf.predict(x_train)
pred=rf.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.4967973645798873
# Mean squared error 8.86956233164762
# r2 Score on test data 0.7961310198551085
# r2 Score on training data 0.9736454416553513

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('Random Forest Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
KNN=KNeighborsRegressor()
KNN.fit(x_train,y_train)
KNN.score(x_train,y_train)
KNN.score(x_test,y_test)
pred1=KNN.predict(x_train)
pred=KNN.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 3.2463630620421275
# Mean squared error 26.518351013188266
# r2 Score on test data 0.3904694533919951
# r2 Score on training data 0.6962875423511964

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('KNeighbors Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
gb.score(x_train,y_train)
gb.score(x_test,y_test)
pred1=gb.predict(x_train)
pred=gb.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.3508054191527274
# Mean squared error 7.303397424239888
# r2 Score on test data 0.8321296892903138
# r2 Score on training data 0.8921488665434049

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('Gradient Boosting Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
lasso.score(x_test,y_test)
lasso.score(x_train,y_train)
pred1=lasso.predict(x_train)
pred=lasso.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 3.2739077723211887
# Mean squared error 19.181473327614867
# r2 Score on test data 0.5591093157974502
# r2 Score on training data 0.6117560026732809

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('Lasso')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
r=Ridge()
r.fit(x_train,y_train)
r.score(x_test,y_test)
r.score(x_train,y_train)
pred1=r.predict(x_train)
pred=r.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 2.0008622355306196
# Mean squared error 10.264145820348036
# r2 Score on test data 0.7640761897589492
# r2 Score on training data 0.7846255846825558

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='b')
plt.title('Ridge')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
dt.score(x_test,y_test)
dt.score(x_train,y_train)
pred1=dt.predict(x_train)
pred=dt.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.9220518565344422
# Mean squared error 16.551252945149255
# r2 Score on test data 0.6195655510522919
# r2 Score on training data 1.0

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='b')
plt.title('Decision Tree Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
et=ExtraTreesRegressor()
et.fit(x_train,y_train)
et.score(x_test,y_test)
et.score(x_train,y_train)
pred1=et.predict(x_train)
pred=et.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1)*100)
# Out:
# Mean absolute Error 1.4489073678394488
# Mean squared error 9.454526678000363
# r2 Score on test data 0.7826854765179206
# r2 Score on training data 100.0

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='b')
plt.title('Extra Trees Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
cv=cross_val_score(rf,x,y,scoring="r2")
print(cv)
print(cv.mean())
print("Difference between R2 score and cross val score is -",(r2_score(y_test,pred)-cv.mean())*100)
# Out:
# [0.84251668 0.71712241 0.84469998 0.81483278 0.79900309]
# 0.8036349897016273
# Difference between R2 score and cross val score is - -2.0949513183706636

# %%
cs1=cross_val_score(gb,x,y)
print(cs1)
print(cs1.mean())
print((r2_score (y_test,pred)-cs1.mean())*100)
# Out:
# [0.86646395 0.74469658 0.89355249 0.83026893 0.81765638]
# 0.8305276660137189
# -4.784218949579822

# %%
cs2=cross_val_score(et,x,y,cv=5,scoring="r2")
print(cs2)
print(cs2.mean())
print((r2_score (y_test,pred)-cs2.mean())*100)
# Out:
# [0.80708362 0.68630168 0.82827377 0.78739162 0.79105941]
# 0.780022022254484
# 0.26634542634366154

# %%
cs3=cross_val_score(lm,x,y)
print(cs3)
print(cs3.mean())
print((r2_score (y_test,pred)-cs3.mean())*100)
# Out:
# [0.80699273 0.7059685  0.83124008 0.77257245 0.7543764 ]
# 0.7742300329026961
# 0.8455443615224545

# %%
cs4=cross_val_score(KNN,x,y)
print(cs4)
print(cs4.mean())
print((r2_score (y_test,pred)-cs4.mean())*100)
# Out:
# [0.57089187 0.50182597 0.6029521  0.49450272 0.46801641]
# 0.5276378170579867
# 25.50476594599339

# %%
cs5=cross_val_score(r,x,y)
print(cs5)
print(cs5.mean())
print((r2_score (y_test,pred)-cs5.mean())*100)
# Out:
# [0.80683833 0.70637356 0.83083258 0.77301183 0.75398023]
# 0.7742073050143885
# 0.8478171503532139

# %%
cs6=cross_val_score(dt,x,y)
print(cs6)
print(cs6.mean())
print((r2_score (y_test,pred)-cs6.mean())*100)
# Out:
# [0.72311522 0.64260865 0.64757693 0.67673441 0.55649056]
# 0.6493051555324009
# 13.338032098551977

# %%
import joblib
joblib.dump(et,'Medical.obj')
et_from_joblib=joblib.load('Medical.obj')
et_from_joblib.predict(x_test)
# Out:
# array([27.86739922, 26.82003166, 23.02161925, 21.83218453, 27.61110983,
#        10.78403907, 18.9451685 , 17.46652096, 15.64071425, 28.77736173,
#        13.0165599 , 35.05326093, 13.34222352, 14.104109  , 12.15849126,
#        16.89512979, 18.82350808, 16.61194194, 21.94309887, 24.28826525,
#        27.99815027, 13.94050156, 18.69423599, 25.08279156, 12.34940876,
#        15.98866279, 19.02507875, 19.03212364, 18.01355447, 33.78564947,
#        22.42741224, 32.78803015, 21.53250516, 10.75149718, 15.57578315,
#        17.01978939, 18.52094623, 28.06548771, 12.91447363, 16.14830995,
#        33.28005954, 16.2398722 , 19.17334818, 29.68603723, 17.35595137,
#        18.54934376, 11.95768053, 11.77310065, 20.56506018, 25.76993302,
#        22.95992022, 22.10630501, 22.25669642, 11.96135678, 24.27845907,
#        30.3423543 , 19.80879465, 28.11045573, 22.2925941 , 18.46854271,
#        23.67834799, 16.79120982, 22.51197551, 10.80038342, 28.63549617,
#        21.85956047, 24.77525904, 16.07103299, 13.15714431, 18.5293774 ,
#        17.07121986, 25.53672821, 34.9258515 , 16.67508657, 35.31079577,
#        32.63276252, 23.91051138, 21.03151357, 20.19627614, 11.76458676,
#        21.20839555, 13.01090806, 33.42463523, 34.75685049, 19.67857677,
#        27.52377812, 24.92487554, 13.01275248, 20.12791947, 11.79086635,
#        21.14080335, 21.43571116, 18.83139516, 32.79664252, 33.9771313 ,
#        24.17961478, 33.87314423, 16.38776267, 19.13200618, 21.70268266,
#        15.57723651, 24.16602031, 33.4403461 , 10.43392976, 30.09424824,
#        23.1343356 , 20.99532659, 34.35698475, 16.99396731, 24.53922387,
#        23.96128361, 35.86827966, 27.56121527, 25.72087099, 22.39604917,
#        23.3743296 , 17.33947705, 26.37955461, 33.91089641, 21.74908803,
#        18.17313654, 24.66781325, 35.1881466 , 17.81398871, 26.32751538,
#        23.88675241, 19.12015467, 17.05779297, 33.97792342, 22.53378001,
#        27.13314476, 30.64639676, 16.61736699, 25.63406458, 16.11884987,
#        12.71147641, 28.4579994 , 13.08902669, 19.59041946, 11.77623952,
#        12.38566083, 23.766732  , 16.25238425, 19.76065028, 23.68546193,
#        27.89747995, 17.38955016, 17.36702016, 20.23438455, 22.11660159,
#  2515.37178484 3402.39208757 2143.66828313 1703.78772487 3315.77048086
#  3045.11568793 1249.07598988 1723.9221827  2361.66430478 3473.71606364
#  2313.27365177 2078.53123868 2245.98733286 1562.53415433 2049.51828858
#  2402.90293519 1584.58461735 2004.39344695 3374.56628406 1808.90179308
#  1641.41063332 2650.92855425 2227.22955756 2913.62771241 2556.24502601
#  1759.11687122 2314.44080792 1519.89206289 2134.97492677 3313.92346305
#  2954.05600728 2064.1395211  2119.53506749 2359.77385641 2160.91334564
#  1612.96562003 1608.43381487 1841.14004872 1048.22823374 1911.24218219
#  2307.99337443 2571.31687126 2203.74046711 1723.77953445 1229.5248684
#  1501.47507784 2301.38143137 2177.78544261 2151.84206113 2146.28617724
#  3482.22697322 2272.4316323  2416.68158146 1857.29619998 1858.19749787
#  1841.66936671 1271.23892041 1727.51697197 1298.27696614 1556.35625452
#  1077.82280138 2889.48582727 2253.0446498  2825.65898076 1979.76641174
#  2108.10103766 2844.00767938 2222.44042639 1904.51658864 1257.90576298
#  1515.26905956 1367.6495109  1707.35404386 3061.77820115 2281.35291365
#  3364.56106882 2040.78016255 2121.23728367 3391.80924914 1747.97453179
#  2149.21881378 2216.25721386 2520.39369632 1472.83649406 1678.49895905
#  2025.66114883 2011.08458585 2041.22619583 1767.59110187 1339.81228684
#  1787.83373494 2299.25377739 2381.0862341  2285.6500816  2152.14793522
#  2238.77823284 2677.96878255 2478.05825564 2411.30062539 3463.96888205
#  2647.3584427 ]

# %% [markdown]
# # FINAL SUMMARY

# %% [markdown]
# OVER VIEW OF PROJECT
# Health insurance charges have risen dramatically over the past decade in response to the rising cost of health care services and are determined by a many factors. The cahrges can be because of many factors like  age, sex, bmi, number of children, smoker,sex and region.
# The purpose of this project is to determine how the above mentioned factors helps in predict health insurance charges by performing exploratory data analysis and predictive modeling on the Health Insurance dataset. In this project following libaries are used for performing various functions on the data set:-
# Numpy, Pandas, Sci-kit learn,matplotlib.pyplot and seaborn.
#
# ABOUT THE DATASET
# 1. age: age of beneficiary
# 2. sex: insurance individuals gender, female, male
# 3. bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to            height.
# 4. children: Number of children covered by health insurance.
# 5. smoker: whether the individuak somke or not.
# 6. region: the beneficiary's residential area  northeast, southeast, southwest, northwest
# 7. charges: Individual medical charges need to be pay.
#
# STEPS IN INVLOVED IN THE PROCESS
# 1. Checked to number of rows n columns present in dataset.
# 2. Checking data type(as all the columns are present in both numerical and categorical form so, converted the data in numerical data).
# 3. Check for the null values in dataset and used heat map to show the same.
# 4. Performed data description in order to check mean,medain etc so, that it will be easy to understand how is skeweed.
# 5. Applied different graphs(bar,his,scatter) on the data to understand in more better way(visual form)
# 6. Check the outliers in the data and removed the same by using Zscore test.
# 7. Checked the skewness of data and removed it by using cuberoot and log transforms.
# 8. Checked the coorelation between independent variable and dependent variable.
# 9. Used train test split method to divide the data(test size is 40%)
# 10.Applied various Regressors model to check which works best on dataset and also applied cross value method to get more acurracy.
#
# CONCLUSION
# Extra Trees Regressor model works best on dataset with 78% accuracy.
