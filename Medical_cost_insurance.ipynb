# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. ABOUT THE DATASET
# Health insurance is a type of insurance that covers medical expenses that arise due to an illness. The main purpose of medical insurance is to receive the best medical care without any strain on finances. Based on certain input features such as age , bmi,no of dependents ,smoker ,region medical insurance is calculated.

# %%
data1=pd.read_csv('Medical_cost_insurance.csv')
data1
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# 2.ABOUT THE VARIABLES
#
# 2.1 The datset is divided into two major variable input n output as mentioned above.The attribute of input variables are as follow-
# 1 - age
# 2 - sex
# 3 - bmi
# 4 - chlidren
# 5 - smoker
# 6 - regions
# The attribute for output variable is:-CHarges
#
# 2.2 We can see that there are 1338 rows and 7 columns including output variable.
#
# 3. Checking the dataset by applying various functions as mentioned below:-
# i head()
# ii tail()
# iii shape( which shows the no. of rows n columns)
# iv data types(here we can see whether my data is numerical or categorical)

# %%
data1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data1.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data1.shape # checking the size of data n out of 7 column 1 is target value
# Out:
# (1338, 7)

# %%
df.dtypes # checking whether data is numerical or categorical
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %% [markdown]
# It can be seen that some of the data is numerical and some are categorical.

# %%
data1.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data1.isnull().sum()   #There is no null value present in the dataset.
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# With the help of above function we can get the detailed information about the data like Range index,Colunm name, non-null count, data type and memory usage.

# %%
sns.heatmap(data1.isnull()) #x axis column name n y axis range, way to check null value by color coding, there only 1 color because there is no null value
# Out:
# <Axes: >

# %% [markdown]
# Inorder to understand the null value in color code format and to have good visual heat map is used to represent the data.As there no null value that why the same color is apperaing on the heat map.

# %%
data1.nunique().to_frame()       #Checked the no. of unique values in the column
# Out:
#              0
# age         47
# sex          2
# bmi        548
# children     6
# smoker       2
# region       4
# charges   1337

# %%
for c in data1.columns:
    print(data1[c].value_counts())
    print('\n')
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# ...

# %%
data1['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data1['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data1['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
data1.duplicated().sum()     #sum of duplicate row present in the dataset
# Out:
# 1

# %%
data1.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# After doing all the required changes in the dataset and as there no negative values present in the dataset it looks good to continue the data analysing.
# Following observations can be done on the bases of describe function.
# i Count of all the coulumns are equal.
# ii Right skewness of data is present because in columns charges because mean is more than median.
# iii Data is also normally distrubted as in many columns for eg.age,bmi,chlidren mean and median have same values. iv There are also chances of outlier in some columns becasuse there is major difference in the values of 75% and max in column charges.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data1.describe(),linewidth=0.3,annot=True,linecolor='blue',cmap='Spectral',fmt="0.2f")
# Out:
# <Axes: >

# %% [markdown]
# Heatmap represention of data after about mean,medain for a better understanding.

# %%
clean_data = {'sex': {'male' : 0 , 'female' : 1} ,
                 'smoker': {'no': 0 , 'yes' : 1},
                   'region' : {'northwest':0, 'northeast':1,'southeast':2,'southwest':3}
               }
data1 = data1.copy()
data1.replace(clean_data, inplace=True)

# %%
data1
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       3  16884.92400
# 1      18    0  33.770         1       0       2   1725.55230
# 2      28    0  33.000         3       0       2   4449.46200
# 3      33    0  22.705         0       0       0  21984.47061
# 4      32    0  28.880         0       0       0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       0       0  10600.54830
# 1334   18    1  31.920         0       0       1   2205.98080
# 1335   18    1  36.850         0       0       2   1629.83350
# 1336   21    1  25.800         0       0       3   2007.94500
# 1337   61    1  29.070         0       1       0  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# As it is observed above the some of the is categorical so, converting  it in numerical data.Inorder to carry out the further processing of the dataset.

# %%
data # After convering the categorical data into numerical data this is the final dataset ready for further steps.

# %% [markdown]
# # Data Visualiation
# 1. Using count plot for better understanding of the variable composition in the data.

# %%
print(data1['sex'].value_counts())
ax=sns.countplot(x='sex',data=data1)
# Out:
# 0    676
# 1    662
# Name: sex, dtype: int64

# %%
print(data1['smoker'].value_counts())
ax=sns.countplot(x='smoker',data=data1)
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
print(data1['age'].value_counts())
ax=sns.countplot(x='age',data=data1)
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
plt.figure(figsize=(12,9))
plt.title('Sex vs Charge')
sns.barplot(x='sex',y='charges',data=data1)
# Out:
# <Axes: title={'center': 'Sex vs Charge'}, xlabel='sex', ylabel='charges'>

# %% [markdown]
# Bar chart is created to visualize the relationship between two variables in the Dataset.

# %%
plt.figure(figsize=(12,9))
plt.title('Smoker vs Charge')
sns.barplot(x='smoker',y='charges',data=data1)
# Out:
# <Axes: title={'center': 'Smoker vs Charge'}, xlabel='smoker', ylabel='charges'>

# %%
plt.figure(figsize=(12,9))
plt.title('Region vs Charges')
sns.barplot(x='region',y='charges',data=data1)
# Out:
# <Axes: title={'center': 'Region vs Charges'}, xlabel='region', ylabel='charges'>

# %%
plt.figure(figsize=(12,9))
plt.title('Children vs Charge')
sns.barplot(x='children',y='charges',data=data1)
# Out:
# <Axes: title={'center': 'Children vs Charge'}, xlabel='children', ylabel='charges'>

# %% [markdown]
# From the below graphical presentation we can the see that thre is right skweness and somewhere normal distribution of data.

# %%
sns.histplot(data=data1,x='bmi',bins=30,kde=True,color='r')
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(data=data1,x='bmi',bins=30,kde=True,color='r')
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(data=data1,x='charges',bins=30,kde=True,color='r')
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.histplot(data1['region'],kde=True,color='r')
# Out:
# <Axes: xlabel='region', ylabel='Count'>

# %%
sns.scatterplot(x='bmi',y='charges',hue='sex',data=data1,palette='bright')
plt.title('BMI VS Charge')
# Out:
# Text(0.5, 1.0, 'BMI VS Charge')

# %%
sns.scatterplot(x='age',y='charges',hue='sex',data=data1,palette='bright')
plt.title('AGE VS Charge')
# Out:
# Text(0.5, 1.0, 'AGE VS Charge')

# %%
sns.scatterplot(x='sex',y='charges',hue='sex',data=data1,palette='bright')
plt.title('SEX VS Charge')
# Out:
# Text(0.5, 1.0, 'SEX VS Charge')

# %%
sns.scatterplot(x='children',y='charges',hue='sex',data=data1,palette='bright')
plt.title('CHILDREN VS Charge')
# Out:
# Text(0.5, 1.0, 'CHILDREN VS Charge')

# %%
sns.scatterplot(x='smoker',y='charges',hue='sex',data=data1,palette='bright')
plt.title('SMOKER VS Charge')
# Out:
# Text(0.5, 1.0, 'SMOKER VS Charge')

# %%
plt.figure(figsize=(10,7))
plt.title('Smoker vs Charge')
sns.barplot(x='smoker',y='charges',data=data1,palette='bright',hue='sex')
# Out:
# <Axes: title={'center': 'Smoker vs Charge'}, xlabel='smoker', ylabel='charges'>

# %%
plt.figure(figsize=(10,7))
plt.title('region vs Charge')
sns.barplot(x='region',y='charges',data=data1,palette='bright',hue='sex')
# Out:
# <Axes: title={'center': 'region vs Charge'}, xlabel='region', ylabel='charges'>

# %%
sns.pairplot(data1)

# %%
sns.boxplot(data=data1['age'], palette="Paired")
# Out:
# <Axes: >

# %%
sns.boxplot(data=data1['bmi'], palette="Paired")
# Out:
# <Axes: >

# %%
sns.boxplot(data=data1['children'], palette="Paired")
# Out:
# <Axes: >

# %%
sns.boxplot(data=data1['region'], palette="Paired")
# Out:
# <Axes: >

# %%
data1.plot(kind='box',subplots=True,layout=(3,4))
# Out:
# age            Axes(0.125,0.653529;0.168478x0.226471)
# sex         Axes(0.327174,0.653529;0.168478x0.226471)
# bmi         Axes(0.529348,0.653529;0.168478x0.226471)
# children    Axes(0.731522,0.653529;0.168478x0.226471)
# smoker         Axes(0.125,0.381765;0.168478x0.226471)
# region      Axes(0.327174,0.381765;0.168478x0.226471)
# charges     Axes(0.529348,0.381765;0.168478x0.226471)
# dtype: object

# %% [markdown]
# From the above plots it is observeed that outliers are present in few columns of the dataset.Inorder to remove thoes outliers zscore is imported and as the threshold value for zscore is between -3 to +3 keeping that in mind removing the outliers.

# %%
from scipy.stats import zscore
out_liers=data1[['bmi','smoker','charges']]
z=np.abs(zscore(out_liers))
z
# Out:
#            bmi    smoker   charges
# 0     0.453320  1.970587  0.298584
# 1     0.509621  0.507463  0.953689
# 2     0.383307  0.507463  0.728675
# 3     1.305531  0.507463  0.719843
# 4     0.292556  0.507463  0.776802
# ...        ...       ...       ...
# 1333  0.050297  0.507463  0.220551
# 1334  0.206139  0.507463  0.914002
# 1335  1.014878  0.507463  0.961596
# 1336  0.797813  0.507463  0.930362
# 1337  0.261388  1.970587  1.311053
#
# [1338 rows x 3 columns]

# %%
data=data1[(z<3).all(axis=1)]
data.shape
# Out:
# (1327, 7)

# %%
df1=print("Data Loose Percentage",(data1.shape[0]-data.shape[0])/data1.shape[0])
# Out:
# Data Loose Percentage 0.008221225710014948

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       3  16884.92400
# 1      18    0  33.770         1       0       2   1725.55230
# 2      28    0  33.000         3       0       2   4449.46200
# 3      33    0  22.705         0       0       0  21984.47061
# 4      32    0  28.880         0       0       0   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       0       0  10600.54830
# 1334   18    1  31.920         0       0       1   2205.98080
# 1335   18    1  36.850         0       0       2   1629.83350
# 1336   21    1  25.800         0       0       3   2007.94500
# 1337   61    1  29.070         0       1       0  29141.36030
#
# [1327 rows x 7 columns]

# %% [markdown]
# Checking the skewness of the data and then removing it by using cuberoot and squareroot method.Skewness values within the range of -1 and -0.5 (negative skewed) or 0.5 and 1(positive skewed).

# %%
data.skew()
# Out:
# age         0.055031
# sex         0.013580
# bmi         0.203726
# children    0.933380
# smoker      1.498166
# region     -0.033371
# charges     1.453405
# dtype: float64

# %%
data[['smoker','bmi','children','charges']]=np.cbrt(data[['smoker','bmi','children','charges']])

# %%
data.skew()
# Out:
# age         0.055031
# sex         0.013580
# bmi        -0.126801
# children   -0.101115
# smoker      1.498166
# region     -0.033371
# charges     0.490528
# dtype: float64

# %%
data.skew().sort_values(ascending=False)
# Out:
# smoker      1.498166
# charges     0.490528
# age         0.055031
# sex         0.013580
# region     -0.033371
# children   -0.101115
# bmi        -0.126801
# dtype: float64

# %%
sns.distplot(data['smoker'],color='b',kde_kws={'shade':True},hist=False)
# Out:
# <Axes: xlabel='smoker', ylabel='Density'>

# %%
data.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020610  0.121131  0.051882 -0.027158  0.003217  0.457594
# sex       0.020610  1.000000 -0.040344 -0.016302 -0.075665 -0.004348 -0.027209
# bmi       0.121131 -0.040344  1.000000  0.020754 -0.009686  0.153162  0.153833
# children  0.051882 -0.016302  0.020754  1.000000  0.013991 -0.006113  0.134573
# smoker   -0.027158 -0.075665 -0.009686  0.013991  1.000000  0.012750  0.725528
# region    0.003217 -0.004348  0.153162 -0.006113  0.012750  1.000000 -0.007685
# charges   0.457594 -0.027209  0.153833  0.134573  0.725528 -0.007685  1.000000

# %%
plt.figure(figsize=(8,7))
sns.heatmap(data.corr(),annot=True) 
plt.show()

# %%
data
# Out:
#       age  sex       bmi  children  smoker  region    charges
# 0      19    1  3.032970   0.00000     1.0       3  25.654666
# 1      18    0  3.232290   1.00000     0.0       2  11.994331
# 2      28    0  3.207534   1.44225     0.0       2  16.447599
# 3      33    0  2.831656   0.00000     0.0       0  28.013799
# 4      32    0  3.068073   0.00000     0.0       0  15.695891
# ...   ...  ...       ...       ...     ...     ...        ...
# 1333   50    0  3.140367   1.44225     0.0       0  21.967271
# 1334   18    1  3.172154   0.00000     0.0       1  13.017690
# 1335   18    1  3.327713   0.00000     0.0       2  11.768318
# 1336   21    1  2.954880   0.00000     0.0       3  12.615872
# 1337   61    1  3.074787   0.00000     1.0       0  30.773007
#
# [1327 rows x 7 columns]

# %%
x=data.iloc[:,0:-1]
x
# Out:
#       age  sex       bmi  children  smoker  region
# 0      19    1  3.032970   0.00000     1.0       3
# 1      18    0  3.232290   1.00000     0.0       2
# 2      28    0  3.207534   1.44225     0.0       2
# 3      33    0  2.831656   0.00000     0.0       0
# 4      32    0  3.068073   0.00000     0.0       0
# ...   ...  ...       ...       ...     ...     ...
# 1333   50    0  3.140367   1.44225     0.0       0
# 1334   18    1  3.172154   0.00000     0.0       1
# 1335   18    1  3.327713   0.00000     0.0       2
# 1336   21    1  2.954880   0.00000     0.0       3
# 1337   61    1  3.074787   0.00000     1.0       0
#
# [1327 rows x 6 columns]

# %%
y=data.iloc[:,-1]
y
# Out:
# 0       25.654666
# 1       11.994331
# 2       16.447599
# 3       28.013799
# 4       15.695891
#           ...
# 1333    21.967271
# 1334    13.017690
# 1335    11.768318
# 1336    12.615872
# 1337    30.773007
# Name: charges, Length: 1327, dtype: float64

# %%
x.shape
# Out:
# (1327, 6)

# %%
y.shape
# Out:
# (1327,)

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %% [markdown]
# X = data_pre.drop('charges',axis=1).values
# y = data_pre['charges'].values.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.40,random_state=42)

# %%
x_train.shape
# Out:
# (796, 6)

# %%
x_test.shape
# Out:
# (531, 6)

# %%
y_train.shape
# Out:
# (796,)

# %%
y_test.shape
# Out:
# (531,)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
lm.score(x_train,y_train)
lm.score(x_test,y_test)
pred1=lm.predict(x_train)
pred=lm.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.9937192223027136
# Mean squared error 10.281412987495111
# r2 Score on test data 0.7636792998533779
# r2 Score on training data 0.783302157649222

# %% [markdown]
#  This model seems to be performing well, with a good R-squared score on the test and train data.

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
rf.score(x_test,y_test)
pred1=rf.predict(x_train)
pred=rf.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.4817525709384378
# Mean squared error 8.891797922320624
# r2 Score on test data 0.7956199295640746
# r2 Score on training data 0.9758407805238947

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('Random Forest Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
KNN=KNeighborsRegressor()
KNN.fit(x_train,y_train)
KNN.score(x_train,y_train)
KNN.score(x_test,y_test)
pred1=KNN.predict(x_train)
pred=KNN.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 3.1333136506766452
# Mean squared error 24.629435557400683
# r2 Score on test data 0.43388662023204183
# r2 Score on training data 0.7078159486897255

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('KNeighbors Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
gb.score(x_train,y_train)
gb.score(x_test,y_test)
pred1=gb.predict(x_train)
pred=gb.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.3577171209691958
# Mean squared error 7.265073293915801
# r2 Score on test data 0.8330105784562013
# r2 Score on training data 0.8973480624106333

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('Gradient Boosting Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
lasso.score(x_test,y_test)
lasso.score(x_train,y_train)
pred1=lasso.predict(x_train)
pred=lasso.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 3.2739077723211887
# Mean squared error 19.181473327614867
# r2 Score on test data 0.5591093157974502
# r2 Score on training data 0.6117560026732809

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='r')
plt.title('Lasso')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
r=Ridge()
r.fit(x_train,y_train)
r.score(x_test,y_test)
r.score(x_train,y_train)
pred1=r.predict(x_train)
pred=r.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.9991214694448676
# Mean squared error 10.301075480703542
# r2 Score on test data 0.7632273528138712
# r2 Score on training data 0.7832579736634578

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='b')
plt.title('Ridge')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
dt.score(x_test,y_test)
dt.score(x_train,y_train)
pred1=dt.predict(x_train)
pred=dt.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1))
# Out:
# Mean absolute Error 1.9889346187973629
# Mean squared error 17.02777681199324
# r2 Score on test data 0.6086125376886509
# r2 Score on training data 1.0

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='b')
plt.title('Decision Tree Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
et=ExtraTreesRegressor()
et.fit(x_train,y_train)
et.score(x_test,y_test)
et.score(x_train,y_train)
pred1=et.predict(x_train)
pred=et.predict(x_test)
print("Mean absolute Error",mean_absolute_error(y_test,pred))
print("Mean squared error",mean_squared_error(y_test,pred))
print("r2 Score on test data",r2_score(y_test,pred))   #0 t0 1
print("r2 Score on training data",r2_score(y_train,pred1)*100)
# Out:
# Mean absolute Error 1.4657085109225572
# Mean squared error 9.61547994445988
# r2 Score on test data 0.778985927762622
# r2 Score on training data 100.0

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred,y=y_test,color='b')
plt.title('Extra Trees Regressor')
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
cv=cross_val_score(rf,x,y,scoring="r2")
print(cv)
print(cv.mean())
print("Difference between R2 score and cross val score is -",(r2_score(y_test,pred)-cv.mean())*100)
# Out:
# [0.84122401 0.7218177  0.84979355 0.81693441 0.80498561]
# 0.8069510549606722
# Difference between R2 score and cross val score is - -2.796512719805022

# %%
cs1=cross_val_score(gb,x,y)
print(cs1)
print(cs1.mean())
print((r2_score (y_test,pred)-cs1.mean())*100)
# Out:
# [0.86277804 0.74021119 0.88687377 0.83438592 0.81570572]
# 0.8279909292347991
# -4.900500147217713

# %%
cs2=cross_val_score(et,x,y,cv=5,scoring="r2")
print(cs2)
print(cs2.mean())
print((r2_score (y_test,pred)-cs2.mean())*100)
# Out:
# [0.80846919 0.68212287 0.83578597 0.78724632 0.79278971]
# 0.7812828118880466
# -0.22968841254246142

# %%
cs3=cross_val_score(lm,x,y)
print(cs3)
print(cs3.mean())
print((r2_score (y_test,pred)-cs3.mean())*100)
# Out:
# [0.8071384  0.70618566 0.82879449 0.77032922 0.75312036]
# 0.7731136243120952
# 0.5872303450526806

# %%
cs4=cross_val_score(KNN,x,y)
print(cs4)
print(cs4.mean())
print((r2_score (y_test,pred)-cs4.mean())*100)
# Out:
# [0.56397138 0.51704851 0.57665459 0.54220781 0.47284391]
# 0.5345452404612054
# 24.444068730141655

# %%
cs5=cross_val_score(r,x,y)
print(cs5)
print(cs5.mean())
print((r2_score (y_test,pred)-cs5.mean())*100)
# Out:
# [0.80697154 0.70656989 0.82841122 0.77076339 0.75274051]
# 0.7730913130922603
# 0.5894614670361675

# %%
cs6=cross_val_score(dt,x,y)
print(cs6)
print(cs6.mean())
print((r2_score (y_test,pred)-cs6.mean())*100)
# Out:
# [0.66538681 0.61887385 0.62026809 0.71614694 0.58693065]
# 0.6415212679487527
# 13.746465981386924

# %%
import joblib
joblib.dump(et,'Medical.obj')
et_from_joblib=joblib.load('Medical.obj')
et_from_joblib.predict(x_test)
# Out:
# array([27.5417956 , 26.84218543, 20.71614352, 21.90051515, 27.06883893,
#        10.78093984, 19.57740652, 17.39049086, 15.52966755, 28.83510262,
#        13.04024834, 35.22695633, 13.45094454, 13.38630463, 12.97810823,
#        17.00507347, 20.35928441, 16.6777542 , 21.8384416 , 24.70282209,
#        26.96434851, 13.94067819, 18.69865655, 25.34148809, 12.46019354,
#        16.68006254, 19.10329359, 18.71651853, 17.91593564, 33.67494437,
#        22.57409232, 32.78361726, 21.48322507, 10.94258213, 16.08888997,
#        17.14680685, 18.82047407, 27.77690655, 13.06604819, 16.10891857,
#        33.31920924, 16.06839741, 19.11305748, 29.54482816, 16.9694617 ,
#        19.20009848, 11.96143639, 11.77310065, 20.63048665, 26.10054018,
#        22.88791622, 22.15636351, 21.71460925, 12.17277801, 24.22344831,
#        30.41057179, 20.08910131, 28.3373891 , 22.09398306, 19.14547107,
#        23.87566648, 16.71596394, 21.94862682, 10.80053046, 28.75608683,
# ...

# %%
import pickle
filename="Medical.pkl1"
pickle.dump(et,open(filename,'wb'))
loaded_model1=pickle.load(open(filename,'rb'))
result=loaded_model1.predict(x_test)
print(result*100)
# Out:
# [2754.17955962 2684.21854319 2071.61435157 2190.05151455 2706.88389301
#  1078.09398378 1957.74065229 1739.04908647 1552.96675513 2883.51026194
#  1304.02483384 3522.69563252 1345.09445361 1338.63046263 1297.81082311
#  1700.50734712 2035.92844115 1667.77541977 2183.84416044 2470.28220875
#  2696.43485144 1394.06781911 1869.86565494 2534.14880947 1246.01935422
#  1668.00625421 1910.32935946 1871.65185281 1791.59356384 3367.49443653
#  2257.40923157 3278.36172563 2148.32250684 1094.25821326 1608.88899748
#  1714.6806845  1882.04740698 2777.69065512 1306.60481949 1610.89185685
#  3331.92092353 1606.83974132 1911.30574754 2954.48281614 1696.94616961
#  1920.00984793 1196.1436395  1177.31006533 2063.04866466 2610.05401809
#  2288.79162245 2215.63635106 2171.46092547 1217.27780142 2422.34483107
#  3041.05717937 2008.91013124 2833.73891031 2209.39830554 1914.54710717
#  2387.56664773 1671.59639412 2194.86268231 1080.0530464  2875.60868337
# ...

# %% [markdown]
# # FINAL SUMMARY

# %% [markdown]
# OVERVIEW OF PROJECT
# Health insurance charges have risen dramatically over the past decade in response to the rising cost of health care services and are determined by a many factors. The cahrges can be because of many factors like  age, sex, bmi, number of children, smoker,sex and region.
# The purpose of this project is to determine how the above mentioned factors helps in predict health insurance charges by performing exploratory data analysis and predictive modeling on the Health Insurance dataset. In this project following libaries are used for performing various functions on the data set:-
# Numpy, Pandas, Sci-kit learn,matplotlib.pyplot and seaborn.
#
# ABOUT THE DATASET
# 1. age: age of beneficiary
# 2. sex: insurance individuals gender, female, male
# 3. bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to            height.
# 4. children: Number of children covered by health insurance.
# 5. smoker: whether the individuak somke or not.
# 6. region: the beneficiary's residential area  northeast, southeast, southwest, northwest
# 7. charges: Individual medical charges need to be pay.
#
# STEPS IN INVLOVED IN THE PROCESS
# 1. Checked to number of rows n columns present in dataset.
# 2. Checking data type(as all the columns are present in both numerical and categorical form so, converted the data in numerical data).
# 3. Check for the null values in dataset and used heat map to show the same.
# 4. Performed data description in order to check mean,medain etc so, that it will be easy to understand how is skeweed.
# 5. Applied different graphs(bar,his,scatter) on the data to understand in more better way(visual form)
# 6. Check the outliers in the data and removed the same by using Zscore test.
# 7. Checked the skewness of data and removed it by using cuberoot and log transforms.
# 8. Checked the coorelation between independent variable and dependent variable.
# 9. Used train test split method to divide the data(test size is 40%)
# 10.Applied various Regressors model to check which works best on dataset and also applied cross value method to get more acurracy.
#
# CONCLUSION
# Extra Trees Regressor model works best on dataset with 78% accuracy.
